# %%
# abesshoppingmall
from tkinter import *
from tkinter import messagebox
from tkinter import ttk
from PIL import Image,ImageTk
from webbrowser import *
import mysql.connector

def click2_1_1():
    open("https://en.wikipedia.org/wiki/Samsung_Galaxy_M30s", new=1)
def click2_1_2():
    open("https://en.wikipedia.org/wiki/IPhone_11_Pro", new=1)
def click2_2_1():
    open("https://gadgets.ndtv.com/lenovo-ideapad-330-8011", new=1)
def click2_2_2():
    open("https://www.digit.in/laptops/apple-macbook-air-11-128gb-price-374.html", new=1)

def first_page():
    login_page.withdraw()
    first_page = Toplevel(login_page)
    first_page.configure(bg='blue')
    first_page.geometry("10000x10000")
    first_page.title("ABES SHOPPING MALL-HOME PAGE")
    logo = PhotoImage(file=r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\download.png").subsample(2, 2)
    logo1 = Label(first_page, image=logo, anchor=N).grid(row=0, column=0, sticky=E)
    title = Label(first_page, text='WELCOME TO ABES SHOPPING MALL\nHOME PAGE', font=("Caviat", 36), fg="red", anchor=N,bg='yellow').grid(row=0, column=0,sticky=E,padx=100)

    mobile_button = Image.open(r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\mobile.jpg")
    img1_1 = ImageTk.PhotoImage(mobile_button)
    btt1_1 = Button(first_page, image=img1_1, command=mobile_func).grid(row=30, column=0, sticky=W, pady=100)
    btt1_1_1 = Button(first_page, text='Mobile Section', font=("Caviat", 10), fg="red", command=mobile_func).grid(row=30,column=0, sticky=SW, pady=100)
    laptop_button = Image.open(r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\laptops.jpg")
    img1_2 = ImageTk.PhotoImage(laptop_button)
    btt1_2 = Button(first_page, image=img1_2, command=laptop_func, anchor=E).grid(row=30, column=50, pady=100,sticky=W)
    btt1_1_2 = Button(first_page, text='Laptop Section', font=("Caviat", 10), fg="red", command=laptop_func).grid(row=30, column=50, sticky=SW, pady=110)
    tb = Label(first_page, text='Thankyou For Visiting\nMade by Ishan Srivastava', font=("Helvetica", 36), fg="red",anchor=SE, bg='yellow').grid(row=1000, column=0,sticky=SW,pady=100,padx=300)
    first_page.mainloop()


def mobile_func():
    login_page.withdraw()
    second_page1=Toplevel(login_page)
    second_page1.configure(bg='blue')
    second_page1.geometry("10000x10000")
    second_page1.title("ABES SHOPPING MALL-MOBILE SECTION")
    logo2_1 = PhotoImage(file=r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\download.png").subsample(2, 2)
    logo1 = Label(second_page1, image=logo2_1, anchor=N).grid(row=0, column=500,sticky=W)
    title = Label(second_page1, text='WELCOME TO ABES SHOPPING MALL\nMOBILE SECTION', font=("Helvetica", 36), fg="red", anchor=N,bg='yellow').grid(
        row=0, column=400)
    mobile2_1 = Image.open(r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\sams.jpg")
    img2_1 = ImageTk.PhotoImage(mobile2_1)
    mb2_1 = Label(second_page1, image=img2_1, anchor=N).grid(row=30, column=0,sticky=W,pady=100)
    mbt2_1 = Label(second_page1, text='Samsung M30s\nRs13999', font=("Caviat", 30), fg="red", anchor=N,bg='yellow').grid(
        row=30, column=400,pady=100,sticky=NW)
    btt2_1 = Button(second_page1, text='DISCRIPTION', font=('Caviat', 20), fg="red",command=click2_1_1,bg='yellow').grid(row=30, column=400, sticky=W,pady=100)
    btt2_1_1 = Button(second_page1, text='ADD TO CART',font=('Caviat',20),fg="red",bg='yellow').grid(row=30,column=400,sticky=SW,pady=100)
    mobile2_2 = Image.open(r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\iphone.jpg")
    img2_2 = ImageTk.PhotoImage(mobile2_2)
    mb2_2 = Label(second_page1, image=img2_2, anchor=N).grid(row=30, column=500, sticky=E, pady=100)
    mbt2_2 = Label(second_page1, text='iPhone 11 pro\nRs99,999', font=("Caviat", 30), fg="red", anchor=N,bg='yellow').grid(row=30, column=400, pady=100, sticky=NE)
    btt2_2 = Button(second_page1, text='DISCRIPTION', font=('Caviat', 20), fg="red",command=click2_1_2,bg='yellow').grid(row=30, column=400,sticky=E,pady=100)
    btt2_2_2 = Button(second_page1, text='ADD TO CART', font=('Caviat', 20), fg="red",bg='yellow').grid(row=30, column=400, sticky=SE,pady=100)
    tb = Label(second_page1, text='Thankyou For Visiting\nMade by Ishan Srivastava', font=("Helvetica", 36), fg="red",
               anchor=CENTER, bg='yellow').grid(row=8000, column=400)
    second_page1.mainloop()

def laptop_func():
    login_page.withdraw()
    second_page2=Toplevel(login_page)
    second_page2.configure(bg='blue')
    second_page2.geometry("10000x10000")
    second_page2.title("ABES ENGINEERING MALL-LAPTOP SECTION")
    logo2_1 = PhotoImage(file=r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\download.png").subsample(2, 2)
    logo1 = Label(second_page2, image=logo2_1, anchor=N).grid(row=0, column=500,sticky=W)
    title = Label(second_page2, text='WELCOME TO ABES SHOPPING MALL\nLAPTOP SECTION', font=("Helvetica", 36), fg="red", anchor=N,bg='yellow').grid(
        row=0, column=400)
    laptop2_1 = Image.open(r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\lenevo.jpg")
    img2_1 = ImageTk.PhotoImage(laptop2_1)
    mb2_1 = Label(second_page2, image=img2_1, anchor=N).grid(row=30, column=0,sticky=W,pady=100)
    mbt2_1 = Label(second_page2, text='Lenevo Ideapad 330\nRs19950', font=("Caviat", 30), fg="red", anchor=N,bg='yellow').grid(
        row=30, column=400,pady=100,sticky=NW)
    btt2_1 = Button(second_page2, text='DISCRIPTION', font=('Caviat', 20), fg="red",command=click2_2_1,bg='yellow').grid(row=30, column=400, sticky=W,pady=100)
    btt2_1_1 = Button(second_page2, text='ADD TO CART',font=('Caviat',20),fg="red",bg='yellow').grid(row=30,column=400,sticky=SW,pady=100)
    laptop2_2 = Image.open(r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\macbook.jpg").resize((250,250),Image.ANTIALIAS)
    img2_2 = ImageTk.PhotoImage(laptop2_2)
    mb2_2 = Label(second_page2, image=img2_2, anchor=N).grid(row=30, column=500, sticky=E, pady=100)
    mbt2_2 = Label(second_page2, text='Apple Macbook pro 11\nRs1,14,999', font=("Caviat", 30), fg="red", anchor=N,bg='yellow').grid(row=30, column=400, pady=100, sticky=NE)
    btt2_2 = Button(second_page2, text='DISCRIPTION', font=('Caviat', 20), fg="red",command=click2_2_2,bg='yellow').grid(row=30, column=400,sticky=E,pady=100)
    btt2_2_2 = Button(second_page2, text='ADD TO CART', font=('Caviat', 20), fg="red",bg='yellow').grid(row=30, column=400, sticky=SE,pady=100)
    tb = Label(second_page2, text='Thankyou For Visiting\nMade by Ishan Srivastava', font=("Helvetica", 36), fg="red",
               anchor=CENTER, bg='yellow').grid(row=500, column=400)
    second_page2.mainloop()

def action_login():
    conn = mysql.connector.connect(host='localhost', username='root', password='password', database='login_mall')
    my_cursor = conn.cursor()
    passr = password_var.get()
    userr = username_var.get()
    sql="SELECT username,password FROM new WHERE username='{}' AND password='{}'".format(userr,passr)
    print(sql)
    my_cursor.execute(sql)
    my_cursor.fetchall()
    n=my_cursor.rowcount
    print("Row count",n)
    if n==1:
        first_page()
    else:
        messagebox.showerror("Error","Please enter correct username and password")
    conn.close()

def action_signup():
    con=mysql.connector.connect(host='localhost',username='root',password='password',database='login_mall')
    my_cursor=con.cursor()
    namr=name_var.get()
    passr=password_signup_var.get()
    userr=user_name_var.get()
    genr=gender_var.get()
    ager=age_var.get()
    my_cursor.execute("INSERT INTO new(name,password,username,gender,age) VALUES(%s,%s,%s,%s,%s)",(namr,passr,userr,genr,ager))
    con.commit()
    con.close()
    messagebox.showinfo("Info", "Successfully signed in\nNow login using your username and password")

login_page = Tk()
login_page.configure(bg='blue')
login_page.geometry("10000x10000")
login_page.title("ABES SHOPPING MALL-LOGIN PAGE")
logo2_1 = PhotoImage(file=r"C:\Users\Ishan Srivastava\PycharmProjects\tkdo\photos\download.png").subsample(2, 2)
logo1 = Label(login_page, image=logo2_1, anchor=W).grid(row=0, column=501, sticky=W)
title = Label(login_page, text='WELCOME TO ABES SHOPPING MALL\nLOGIN PAGE', font=("Helvetica", 36), fg="red",anchor=CENTER, bg='yellow').grid(row=0, column=500,sticky=E)
login=Label(login_page, text='LOGIN IN:', font=("Helvetica", 20), fg="red").grid(row=1, column=1000,pady=100)
signup=Label(login_page, text='SIGN UP:', font=("Helvetica", 20), fg="red").grid(row=1, column=500,pady=100,sticky=W)
username = Label(login_page, text='username:', font=("Helvetica", 20), fg="black",anchor=N, bg='blue').grid(row=2, column=1000,sticky=W)
password = Label(login_page, text='password:', font=("Helvetica", 20), fg="black",anchor=N, bg='blue').grid(row=3,column=1000,sticky=W)
name = Label(login_page, text='Enter Your Name:', font=("Helvetica", 20), fg="black",anchor=N, bg='blue').grid(row=2, column=500,sticky=W)
password_signup = Label(login_page, text='Enter Your Password:', font=("Helvetica", 20), fg="black",anchor=N, bg='blue').grid(row=3, column=500,sticky=W)
user_name= Label(login_page, text='Enter Your Username:', font=("Helvetica", 20), fg="black",anchor=N, bg='blue').grid(row=4, column=500,sticky=W)
gender = Label(login_page, text='Enter Your Gender:', font=("Helvetica", 20), fg="black",anchor=N, bg='blue').grid(row=5, column=500,sticky=W)
age = Label(login_page, text='Enter Your Age:', font=("Helvetica", 20), fg="black",anchor=N, bg='blue').grid(row=6, column=500,sticky=W)
username_var=StringVar()
username_entrybox=Entry(login_page,width=30,textvariable=username_var).grid(row=2,column=1001,sticky=W)
password_var=StringVar()
password_entrybox=Entry(login_page,width=30,textvariable=password_var,show='*').grid(row=3,column=1001,sticky=W)
name_var=StringVar()
name_entrybox=Entry(login_page,width=30,textvariable=name_var).grid(row=2,column=500,sticky=W,padx=300)
password_signup_var=StringVar()
password_signup_entrybox=Entry(login_page,width=30,textvariable=password_signup_var,show='*').grid(row=3,column=500,sticky=W,padx=300)
user_name_var=StringVar()
user_name_entrybox=Entry(login_page,width=30,textvariable=user_name_var).grid(row=4,column=500,sticky=W,padx=300)
val=['Male','Female','Others']
gender_var=StringVar()
gender_combobox=ttk.Combobox(login_page,width=30,values=val,state='readonly',textvariable=gender_var)
gender_combobox.current(0)
gender_combobox.grid(row=5,column=500,sticky=W,padx=300)
age_var=StringVar()
age_entrybox=Entry(login_page,width=30,textvariable=age_var).grid(row=6,column=500,sticky=W,padx=300)
btt1=Button(login_page,text='Submit',font=("Helvetica", 15),fg="black",command=action_login).grid(row=4,column=1000,sticky=W)
btt2=Button(login_page,text='Submit',font=("Helvetica", 15),fg="black",command=action_signup).grid(row=7,column=500,sticky=W)
tb = Label(login_page, text='Thankyou For Visiting\nMade by Ishan Srivastava', font=("Helvetica", 36), fg="red",anchor=S, bg='yellow').grid(row=9900, column=500,sticky=S,padx=200)
login_page.mainloop()
